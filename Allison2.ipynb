# %% [markdown]
# <a href="https://colab.research.google.com/github/abkerper/project_voting/blob/main/Allison2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/abkerper/project_voting
# Out:
# Cloning into 'project_voting'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 110 (delta 28), reused 19 (delta 11), pack-reused 62
# Receiving objects: 100% (110/110), 31.44 MiB | 7.94 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# Updating files: 100% (47/47), done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df_results = pd.read_csv('./project_voting/data/county_results.csv', low_memory = False)

# %%
df_results
# Out:
#       Unnamed: 0.1  Unnamed: 0  year     state state_po      county_name  \
# 0                0       11233  2000  VIRGINIA       VA     CHARLES CITY
# 1                1       11613  2000  VIRGINIA       VA        LEXINGTON
# 2                2       11310  2000  VIRGINIA       VA          GRAYSON
# 3                3       11490  2000  VIRGINIA       VA            SMYTH
# 4                4       11426  2000  VIRGINIA       VA             PAGE
# ...            ...         ...   ...       ...      ...              ...
# 1418          1418       70820  2020  VIRGINIA       VA        GOOCHLAND
# 1419          1419       71875  2020  VIRGINIA       VA     ROANOKE CITY
# 1420          1420       71735  2020  VIRGINIA       VA   LYNCHBURG CITY
# 1421          1421       70557  2020  VIRGINIA       VA       BUCKINGHAM
# 1422          1422       71839  2020  VIRGINIA       VA  PORTSMOUTH CITY
#
#       county_fips        office          candidate       party  \
# ...

# %%
years = [2000, 2004, 2008, 2012, 2016, 2020]
results_by_year = {}
for year in years:
    results_by_year[year] = df_results[df_results['year'] == year]

# %%
years = [2000, 2004, 2008, 2012, 2016, 2020]
party_results_by_year = {}
for year in years:
  party_results_by_year[year] = results_by_year[year]['party'].value_counts()

# %%
party_results_by_year = pd.DataFrame(party_results_by_year)

# %%
party_results_by_year
# Out:
#             2000  2004  2008  2012  2016  2020
# party
# REPUBLICAN   606   100    84    86    92    77
# DEMOCRAT     168    29    45    43    37    56
