# %% [markdown]
# <a href="https://colab.research.google.com/github/abkerper/project_voting/blob/main/Allison2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/abkerper/project_voting
# Out:
# fatal: destination path 'project_voting' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df_wins = pd.read_csv('./project_voting/data/county_wins.csv', low_memory = False)
df_rep_dem = pd.read_csv('./project_voting/data/rep_dem_votes.csv', low_memory = False)

# %% [markdown]
# ## **Compare wins by year and county**

# %%
years = [2000, 2004, 2008, 2012, 2016, 2020]
wins_by_year = {}
for year in years:
    wins_by_year[year] = df_wins[df_wins['year'] == year]

# %%
party_wins_by_year = {}
for year in years:
  party_wins_by_year[year] = wins_by_year[year]['party'].value_counts()

# %%
party_wins_by_year = pd.DataFrame(party_wins_by_year)
party_wins_by_year
# Out:
#             2000  2004  2008  2012  2016  2020
# party
# REPUBLICAN   101   100    84    86    92    77
# DEMOCRAT      28    29    45    43    37    56

# %%
counties_per_year = {}
for year in years:
  county_names = wins_by_year[year]['county_name'].values
  county_names = list(set(county_names))
  counties_per_year[year] = county_names

# %%
for year in years:
  print(year, ':', len(counties_per_year[year]))
# Out:
# 2000 : 129
# 2004 : 129
# 2008 : 129
# 2012 : 129
# 2016 : 129
# 2020 : 133

# %% [markdown]
# There are 4 more counties counted in 2020. Won't use them for comparison purposes.

# %%
# wins_by_county = {}
# for year in years:
#   wins_by_county[year] = pd.DataFrame
#   county_list = wins_by_year[year]['county_name'].values
#   county_list= list(set(county_names))
#   for county in county_list:
#     wins_by_county[year] = df_wins[df_wins['county_name'] == county]

# %%
wins_by_county = {}
county_list = wins_by_year[2000]['county_name'].values
county_list= list(set(county_names))
results_by_county = {}
for county in county_list:
    wins_by_county[county] = df_wins[df_wins['county_name'] == county]

# %%
wins_by_county['LOUDOUN']
# Out:
#      Unnamed: 0.1  Unnamed: 0  year     state state_po county_name  \
# 82             82       11370  2000  VIRGINIA       VA     LOUDOUN
# 211           211       20995  2004  VIRGINIA       VA     LOUDOUN
# 340           340       30345  2008  VIRGINIA       VA     LOUDOUN
# 469           469       39696  2012  VIRGINIA       VA     LOUDOUN
# 598           598       49047  2016  VIRGINIA       VA     LOUDOUN
# 729           729       71003  2020  VIRGINIA       VA     LOUDOUN
#
#      county_fips        office          candidate       party  candidatevotes  \
# 82         51107  US PRESIDENT     GEORGE W. BUSH  REPUBLICAN           42453
# 211        51107  US PRESIDENT     GEORGE W. BUSH  REPUBLICAN           60382
# 340        51107  US PRESIDENT       BARACK OBAMA    DEMOCRAT           74845
# 469        51107  US PRESIDENT       BARACK OBAMA    DEMOCRAT           82479
# 598        51107  US PRESIDENT    HILLARY CLINTON    DEMOCRAT          100795
# ...

# %% [markdown]
# ## **Compare Rep/Dem votes by year and county**

# %%
df_rep_dem['rep_dem_difference'] = df_rep_dem.groupby(['year', 'county_name'])['candidatevotes'].diff()

# %%
years = [2000, 2004, 2008, 2012, 2016, 2020]
rep_dem_by_year = {}
for year in years:
    rep_dem_by_year[year] = df_rep_dem[df_rep_dem['year'] == year]

# %%
rep_dem_by_year[2000].head(12)
# Out:
#     Unnamed: 0.1  Unnamed: 0  year     state state_po county_name  \
# 0              0       11161  2000  VIRGINIA       VA    ACCOMACK
# 1              1       11162  2000  VIRGINIA       VA    ACCOMACK
# 2              4       11165  2000  VIRGINIA       VA   ALBEMARLE
# 3              5       11166  2000  VIRGINIA       VA   ALBEMARLE
# 4              8       11169  2000  VIRGINIA       VA   ALLEGHANY
# 5              9       11170  2000  VIRGINIA       VA   ALLEGHANY
# 6             12       11173  2000  VIRGINIA       VA      AMELIA
# 7             13       11174  2000  VIRGINIA       VA      AMELIA
# 8             16       11177  2000  VIRGINIA       VA     AMHERST
# 9             17       11178  2000  VIRGINIA       VA     AMHERST
# 10            20       11181  2000  VIRGINIA       VA  APPOMATTOX
# 11            21       11182  2000  VIRGINIA       VA  APPOMATTOX
#
#     county_fips        office       candidate       party  candidatevotes  \
# ...

# %%
df_rep_dem['rep_dem_difference'] = df_rep_dem.groupby(['year', 'county_name'])['candidatevotes'].diff()

# %%
df_rep_dem[df_rep_dem['year'] == 2020]
# Out:
#       Unnamed: 0.1  Unnamed: 0  year     state state_po      county_name  \
# 1340          2144       70379  2020  VIRGINIA       VA         ACCOMACK
# 1341          2145       70380  2020  VIRGINIA       VA         ACCOMACK
# 1342          2146       70381  2020  VIRGINIA       VA         ACCOMACK
# 1343          2153       70388  2020  VIRGINIA       VA         ACCOMACK
# 1344          2154       70389  2020  VIRGINIA       VA         ACCOMACK
# ...            ...         ...   ...       ...      ...              ...
# 2131          3725       71960  2020  VIRGINIA       VA  WINCHESTER CITY
# 2132          3726       71961  2020  VIRGINIA       VA  WINCHESTER CITY
# 2133          3733       71968  2020  VIRGINIA       VA  WINCHESTER CITY
# 2134          3734       71969  2020  VIRGINIA       VA  WINCHESTER CITY
# 2135          3735       71970  2020  VIRGINIA       VA  WINCHESTER CITY
#
#       county_fips        office          candidate       party  \
# ...

# %%
county_list = wins_by_year[2000]['county_name'].values
county_list= list(set(county_names))
for year in years:
  for county in county_list:
    county_rows = rep_dem_by_year[year][rep_dem_by_year[year]['county_name'] == county]
    difference = county_rows['candidatevotes'].diff()
    rep_dem_by_year[year]['difference'] = difference
# Out:
# <ipython-input-32-d3331bcf4bf0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rep_dem_by_year[year]['difference'] = difference

# %%
rep_dem_by_year[2000]
# Out:
#      Unnamed: 0.1  Unnamed: 0  year     state state_po   county_name  \
# 0               0       11161  2000  VIRGINIA       VA      ACCOMACK
# 1               1       11162  2000  VIRGINIA       VA      ACCOMACK
# 2               4       11165  2000  VIRGINIA       VA     ALBEMARLE
# 3               5       11166  2000  VIRGINIA       VA     ALBEMARLE
# 4               8       11169  2000  VIRGINIA       VA     ALLEGHANY
# ..            ...         ...   ...       ...      ...           ...
# 263           525       11686  2000  VIRGINIA       VA    WAYNESBORO
# 264           528       11689  2000  VIRGINIA       VA  WILLIAMSBURG
# 265           529       11690  2000  VIRGINIA       VA  WILLIAMSBURG
# 266           532       11693  2000  VIRGINIA       VA    WINCHESTER
# 267           533       11694  2000  VIRGINIA       VA    WINCHESTER
#
#      county_fips        office       candidate       party  candidatevotes  \
# ...
