# %% [markdown]
# <a href="https://colab.research.google.com/github/abkerper/project_voting/blob/main/Kiera_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/abkerper/project_voting
# Out:
# Cloning into 'project_voting'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 129 (delta 41), reused 19 (delta 11), pack-reused 62
# Receiving objects: 100% (129/129), 31.45 MiB | 7.04 MiB/s, done.
# Resolving deltas: 100% (65/65), done.
# Updating files: 100% (48/48), done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df_results = pd.read_csv('/content/county_results1.csv', low_memory = False)

# %%
df_results
# Out:
#      Unnamed: 0.1  Unnamed: 0  year     state state_po  county_name  \
# 0               0       11190  2000  VIRGINIA       VA      AUGUSTA
# 1               1       11554  2000  VIRGINIA       VA  BUENA VISTA
# 2               2       11398  2000  VIRGINIA       VA   MONTGOMERY
# 3               3       11250  2000  VIRGINIA       VA        CRAIG
# 4               4       11238  2000  VIRGINIA       VA    CHARLOTTE
# ..            ...         ...   ...       ...      ...          ...
# 773           773       71169  2020  VIRGINIA       VA       ORANGE
# 774           774       71685  2020  VIRGINIA       VA   GALAX CITY
# 775           775       70391  2020  VIRGINIA       VA    ALBEMARLE
# 776           776       70631  2020  VIRGINIA       VA       CLARKE
# 777           777       70545  2020  VIRGINIA       VA     BUCHANAN
#
#      county_fips        office          candidate       party  candidatevotes  \
# ...

# %%
len(df_results['year'] == 2000)
# Out:
# 778

# %%
len(df_results['year'] == 2004)
# Out:
# 778

# %%
len(df_results['year'] == 2008)
# Out:
# 778

# %%
years = [2000, 2004, 2008, 2012, 2016, 2020]
results_by_year = {}
for year in years:
    results_by_year[year] = df_results[df_results['year'] == year]

# %%
party_results_by_year = {}
for year in years:
  party_results_by_year[year] = results_by_year[year]['party'].value_counts()

# %%
party_results_by_year = pd.DataFrame(party_results_by_year)

# %%
party_results_by_year
# Out:
#             2000  2004  2008  2012  2016  2020
# party
# REPUBLICAN   101   100    84    86    92    77
# DEMOCRAT      28    29    45    43    37    56

# %%
party_results_by_year['total_votes'] = party_results_by_year[2000]+ party_results_by_year[2004]+party_results_by_year[2008]+party_results_by_year[2012]+party_results_by_year[2016]+party_results_by_year[2020]

# %%
party_results_by_year
# Out:
#             2000  2004  2008  2012  2016  2020  total_votes
# party
# REPUBLICAN   101   100    84    86    92    77          540
# DEMOCRAT      28    29    45    43    37    56          238

# %%
# Full sample promotion averages and difference:
republican_0 = party_results_by_year[]
democrat_0 = df.loc[ df['party'] =='DEMOCRAT', '2000' ].sum()
diff_0 =  republican_0 - democrat_0
print(diff_0)

# Female data:
df_R = df.loc[ df['party'] =='REPUBLICAN', 'total_votes' ]
N_R = df_f.shape[0]
# Male data:
df_D = df.loc[ df['party'] =='male', 'promoted' ]
N_D = df_m.shape[0]

# Simulation:
S = 1000
rate_F = np.zeros(S) # Female promotion rate
rate_M = np.zeros(S) # Male promotion rate
diff = np.zeros(S)  # Difference in promotion rates

# Bootstrapping:
for s in range(S):
    sample_R = df_R.sample(N_R,axis=0,replace=True) # Resample women
    rate_R[s] = sample_R.mean() # Mean promotion rate, women
    sample_D = df_m.sample(N_D,axis=0,replace=True) # Resample men
    rate_D[s] = sample_D.mean() # Mean promotion rate, men
    diff[s] = rate_F[s]-rate_M[s] # Difference in rates

# Combine male and female result into one dataframe for plotting:
rdf_R = pd.DataFrame({'sex':'female','promotion_rate':rate_F})
rdf_D = pd.DataFrame({'sex':'male','promotion_rate':rate_M})
rdf = pd.concat([rdf_R,rdf_D],axis=0)

# Density plot of promotion rates:
#sns.kdeplot(data=rdf,x='promotion_rate',hue='sex')
#plt.show()

# ECDF of promotion rates:
#sns.ecdfplot(data=rdf,x='promotion_rate',hue='sex')
#plt.show()
# Out:
#   File "<ipython-input-39-a8571ce0c605>", line 2
#     republican_0 = party_results_by_year[]
#                                          ^
# SyntaxError: invalid syntax

# %%
counties_per_year = {}
for year in years:
  county_names = results_by_year[year]['county_name'].values
  county_names = list(set(county_names))
  counties_per_year[year] = county_names

# %%
for year in years:
  print(year, ':', len(counties_per_year[year]))
# Out:
# 2000 : 129
# 2004 : 129
# 2008 : 129
# 2012 : 129
# 2016 : 129
# 2020 : 133

# %% [markdown]
# There are 4 more counties counted in 2020. Won't use them for comparison purposes.

# %%
results_by_county = {}
for year in years:
  results_by_county[year] = pd.DataFrame
  county_list = results_by_year[year]['county_name'].values
  county_list= list(set(county_names))
  for county in county_list:
    results_by_county[year] = df_results[df_results['county_name'] == county]

# %%
county_list = results_by_year[2000]['county_name'].values
county_list= list(set(county_names))
results_by_county = {}
for county in county_list:
    results_by_county[county] = df_results[df_results['county_name'] == county]

# %%
results_by_county_alb= results_by_county['ALBEMARLE']

# %%
results_by_county_alb.head()
# Out:
#      Unnamed: 0.1  Unnamed: 0  year     state state_po county_name  \
# 126           126       11166  2000  VIRGINIA       VA   ALBEMARLE
# 255           255       20841  2004  VIRGINIA       VA   ALBEMARLE
# 384           384       30192  2008  VIRGINIA       VA   ALBEMARLE
# 513           513       39543  2012  VIRGINIA       VA   ALBEMARLE
# 642           642       48894  2016  VIRGINIA       VA   ALBEMARLE
#
#      county_fips        office        candidate       party  candidatevotes  \
# 126        51003  US PRESIDENT   GEORGE W. BUSH  REPUBLICAN           18291
# 255        51003  US PRESIDENT       JOHN KERRY    DEMOCRAT           22088
# 384        51003  US PRESIDENT     BARACK OBAMA    DEMOCRAT           29792
# 513        51003  US PRESIDENT     BARACK OBAMA    DEMOCRAT           29757
# 642        51003  US PRESIDENT  HILLARY CLINTON    DEMOCRAT           33345
#
#      totalvotes   version   mode
# 126       36846  20220315  TOTAL
# 255       43726  20220315  TOTAL
# ...

# %%
pd.DataFrame(results_by_county.items())
# Out:
#                    0                                                  1
# 0     KING AND QUEEN       Unnamed: 0.1  Unnamed: 0  year     state ...
# 1           NEW KENT       Unnamed: 0.1  Unnamed: 0  year     state ...
# 2              GILES       Unnamed: 0.1  Unnamed: 0  year     state ...
# 3              FLOYD       Unnamed: 0.1  Unnamed: 0  year     state ...
# 4          DINWIDDIE       Unnamed: 0.1  Unnamed: 0  year     state ...
# ..               ...                                                ...
# 128          PATRICK       Unnamed: 0.1  Unnamed: 0  year     state ...
# 129           ORANGE       Unnamed: 0.1  Unnamed: 0  year     state ...
# 130             WISE       Unnamed: 0.1  Unnamed: 0  year     state ...
# 131    RICHMOND CITY       Unnamed: 0.1  Unnamed: 0  year     state ...
# 132  PORTSMOUTH CITY       Unnamed: 0.1  Unnamed: 0  year     state ...
#
# [133 rows x 2 columns]
