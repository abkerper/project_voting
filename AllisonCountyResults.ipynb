# %% [markdown]
# <a href="https://colab.research.google.com/github/abkerper/project_voting/blob/main/AllisonCountyResults.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/DS3001/project_voting
# Out:
# fatal: destination path 'project_voting' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data_df = pd.read_csv("./project_voting/data/voting_VA.csv")
data_df.head(20)
# Out:
#     Unnamed: 0  year     state state_po county_name  county_fips  \
# 0        11161  2000  VIRGINIA       VA    ACCOMACK        51001
# 1        11162  2000  VIRGINIA       VA    ACCOMACK        51001
# 2        11163  2000  VIRGINIA       VA    ACCOMACK        51001
# 3        11164  2000  VIRGINIA       VA    ACCOMACK        51001
# 4        11165  2000  VIRGINIA       VA   ALBEMARLE        51003
# 5        11166  2000  VIRGINIA       VA   ALBEMARLE        51003
# 6        11167  2000  VIRGINIA       VA   ALBEMARLE        51003
# 7        11168  2000  VIRGINIA       VA   ALBEMARLE        51003
# 8        11169  2000  VIRGINIA       VA   ALLEGHANY        51005
# 9        11170  2000  VIRGINIA       VA   ALLEGHANY        51005
# 10       11171  2000  VIRGINIA       VA   ALLEGHANY        51005
# 11       11172  2000  VIRGINIA       VA   ALLEGHANY        51005
# 12       11173  2000  VIRGINIA       VA      AMELIA        51007
# 13       11174  2000  VIRGINIA       VA      AMELIA        51007
# 14       11175  2000  VIRGINIA       VA      AMELIA        51007
# 15       11176  2000  VIRGINIA       VA      AMELIA        51007
# 16       11177  2000  VIRGINIA       VA     AMHERST        51009
# 17       11178  2000  VIRGINIA       VA     AMHERST        51009
# 18       11179  2000  VIRGINIA       VA     AMHERST        51009
# 19       11180  2000  VIRGINIA       VA     AMHERST        51009
#
#           office       candidate       party  candidatevotes  totalvotes  \
# 0   US PRESIDENT         AL GORE    DEMOCRAT            5092       11925
# 1   US PRESIDENT  GEORGE W. BUSH  REPUBLICAN            6352       11925
# 2   US PRESIDENT     RALPH NADER       GREEN             220       11925
# 3   US PRESIDENT           OTHER       OTHER             261       11925
# 4   US PRESIDENT         AL GORE    DEMOCRAT           16255       36846
# 5   US PRESIDENT  GEORGE W. BUSH  REPUBLICAN           18291       36846
# 6   US PRESIDENT     RALPH NADER       GREEN            2043       36846
# 7   US PRESIDENT           OTHER       OTHER             257       36846
# 8   US PRESIDENT         AL GORE    DEMOCRAT            2214        5123
# 9   US PRESIDENT  GEORGE W. BUSH  REPUBLICAN            2808        5123
# 10  US PRESIDENT     RALPH NADER       GREEN              62        5123
# 11  US PRESIDENT           OTHER       OTHER              39        5123
# 12  US PRESIDENT         AL GORE    DEMOCRAT            1754        4788
# 13  US PRESIDENT  GEORGE W. BUSH  REPUBLICAN            2947        4788
# 14  US PRESIDENT     RALPH NADER       GREEN              40        4788
# 15  US PRESIDENT           OTHER       OTHER              47        4788
# 16  US PRESIDENT         AL GORE    DEMOCRAT            4812       11712
# 17  US PRESIDENT  GEORGE W. BUSH  REPUBLICAN            6660       11712
# 18  US PRESIDENT     RALPH NADER       GREEN             135       11712
# 19  US PRESIDENT           OTHER       OTHER             105       11712
#
#      version   mode
# 0   20220315  TOTAL
# 1   20220315  TOTAL
# 2   20220315  TOTAL
# 3   20220315  TOTAL
# 4   20220315  TOTAL
# 5   20220315  TOTAL
# 6   20220315  TOTAL
# 7   20220315  TOTAL
# 8   20220315  TOTAL
# 9   20220315  TOTAL
# 10  20220315  TOTAL
# 11  20220315  TOTAL
# 12  20220315  TOTAL
# 13  20220315  TOTAL
# 14  20220315  TOTAL
# 15  20220315  TOTAL
# 16  20220315  TOTAL
# 17  20220315  TOTAL
# 18  20220315  TOTAL
# 19  20220315  TOTAL

# %% [markdown]
# # **Create Df with wins by year**

# %%
data_df['year'].value_counts()
# Out:
# year
# 2020    1592
# 2000     536
# 2004     402
# 2008     402
# 2012     402
# 2016     402
# Name: count, dtype: int64

# %%
data_2000 = data_df[(data_df['year'] == 2000)]
data_2004 = data_df[(data_df['year'] == 2004)]
data_2008 = data_df[(data_df['year'] == 2008)]
data_2012 = data_df[(data_df['year'] == 2012)]
data_2016 = data_df[(data_df['year'] == 2016)]
data_2020 = data_df[(data_df['year'] == 2020)]

# %%
data_by_year = [data_2000, data_2004, data_2008, data_2012, data_2016, data_2020]
df_wins = pd.DataFrame()

# %%
for year in data_by_year:
  wins = pd.DataFrame()
  county_names = year['county_name'].values
  county_names = list(set(county_names))
  for county in county_names:
    county_rows = year[year['county_name'] == county]
    max_votes = county_rows['candidatevotes'].idxmax()
    winning_row = year.loc[max_votes]
    wins = pd.concat([wins, pd.DataFrame([winning_row])], ignore_index=True)
  df_wins = pd.concat([df_wins, wins], ignore_index = True)

# %%
df_wins
# Out:
#      Unnamed: 0  year     state state_po    county_name  county_fips  \
# 0         11554  2000  VIRGINIA       VA    BUENA VISTA        51530
# 1         11310  2000  VIRGINIA       VA        GRAYSON        51077
# 2         11390  2000  VIRGINIA       VA    MECKLENBURG        51117
# 3         11650  2000  VIRGINIA       VA       POQUOSON        51735
# 4         11562  2000  VIRGINIA       VA     CHESAPEAKE        51550
# ..          ...   ...       ...      ...            ...          ...
# 773       71373  2020  VIRGINIA       VA          SMYTH        51173
# 774       70593  2020  VIRGINIA       VA        CARROLL        51035
# 775       71481  2020  VIRGINIA       VA   WESTMORELAND        51193
# 776       71896  2020  VIRGINIA       VA     SALEM CITY        51775
# 777       71219  2020  VIRGINIA       VA  PRINCE EDWARD        51147
#
#            office          candidate       party  candidatevotes  totalvotes  \
# 0    US PRESIDENT     GEORGE W. BUSH  REPUBLICAN             980        1975
# 1    US PRESIDENT     GEORGE W. BUSH  REPUBLICAN            4236        6852
# 2    US PRESIDENT     GEORGE W. BUSH  REPUBLICAN            6600       11654
# 3    US PRESIDENT     GEORGE W. BUSH  REPUBLICAN            4271        5861
# 4    US PRESIDENT     GEORGE W. BUSH  REPUBLICAN           39684       74585
# ..            ...                ...         ...             ...         ...
# 773  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            8038       14136
# 774  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            8706       15657
# 775  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            3160        9948
# 776  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            4710       13051
# 777  US PRESIDENT  JOSEPH R BIDEN JR    DEMOCRAT            3048        9575
#
#       version          mode
# 0    20220315         TOTAL
# 1    20220315         TOTAL
# 2    20220315         TOTAL
# 3    20220315         TOTAL
# 4    20220315         TOTAL
# ..        ...           ...
# 773  20220315  ELECTION DAY
# 774  20220315  ELECTION DAY
# 775  20220315  ELECTION DAY
# 776  20220315      ABSENTEE
# 777  20220315      ABSENTEE
#
# [778 rows x 13 columns]

# %%
df_wins.to_csv('wins.csv')

# %% [markdown]
# # **Create Df with Dem and Rep votes per year**

# %%
rep_dem_df = data_df[(data_df['party'] == 'DEMOCRAT') | (data_df['party'] == 'REPUBLICAN')]

# %%
rep_dem_2020 = rep_dem_df[rep_dem_df['year'] == 2020]

# %%
county_names = rep_dem_2020['county_name'].values
county_names = list(set(county_names))
for county in county_names:
  dem_rows_sum = rep_dem_df[(rep_dem_df['county_name'] == county) | (rep_dem_df['party'] == 'DEMOCRAT')]['candidatevotes'].sum()
  print(dem_rows_sum)
  rep_dem_df.loc[(rep_dem_df['county_name'] == county) | (rep_dem_df['party'] == 'DEMOCRAT') | (rep_dem_df['mode'] == 'ABSENTEE'), 'totalvotes'] = dem_rows_sum
  rep_rows_sum = rep_dem_df[(rep_dem_df['county_name'] == county) | (rep_dem_df['party'] == 'REPUBLICAN')]['candidatevotes'].sum()
  rep_dem_df.loc[(rep_dem_df['county_name'] == county) | (rep_dem_df['party'] == 'REPUBLICAN') | (rep_dem_df['mode'] == 'ABSENTEE'), 'totalvotes'] = rep_rows_sum

# %%
rep_dem_df[rep_dem_df['year'] == 2020]
# Out:
#       Unnamed: 0  year     state state_po      county_name  county_fips  \
# 2144       70379  2020  VIRGINIA       VA         ACCOMACK        51001
# 2145       70380  2020  VIRGINIA       VA         ACCOMACK        51001
# 2146       70381  2020  VIRGINIA       VA         ACCOMACK        51001
# 2153       70388  2020  VIRGINIA       VA         ACCOMACK        51001
# 2154       70389  2020  VIRGINIA       VA         ACCOMACK        51001
# ...          ...   ...       ...      ...              ...          ...
# 3725       71960  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3726       71961  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3733       71968  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3734       71969  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3735       71970  2020  VIRGINIA       VA  WINCHESTER CITY        51840
#
#             office          candidate       party  candidatevotes  totalvotes  \
# 2144  US PRESIDENT  JOSEPH R BIDEN JR    DEMOCRAT            5495    11021003
# 2145  US PRESIDENT  JOSEPH R BIDEN JR    DEMOCRAT            2072    11021003
# 2146  US PRESIDENT  JOSEPH R BIDEN JR    DEMOCRAT              11    11021003
# 2153  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            3084    11021003
# 2154  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            6078    11045436
# ...            ...                ...         ...             ...         ...
# 3725  US PRESIDENT  JOSEPH R BIDEN JR    DEMOCRAT            1466    11021003
# 3726  US PRESIDENT  JOSEPH R BIDEN JR    DEMOCRAT              51    11021003
# 3733  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            2825    11021003
# 3734  US PRESIDENT     DONALD J TRUMP  REPUBLICAN            2370    11002778
# 3735  US PRESIDENT     DONALD J TRUMP  REPUBLICAN              26    11002778
#
#        version          mode
# 2144  20220315      ABSENTEE
# 2145  20220315  ELECTION DAY
# 2146  20220315   PROVISIONAL
# 2153  20220315      ABSENTEE
# 2154  20220315  ELECTION DAY
# ...        ...           ...
# 3725  20220315  ELECTION DAY
# 3726  20220315   PROVISIONAL
# 3733  20220315      ABSENTEE
# 3734  20220315  ELECTION DAY
# 3735  20220315   PROVISIONAL
#
# [796 rows x 13 columns]

# %%
combined_2020_df
# Out:
#            county_name  candidatevotes_DEMOCRAT  candidatevotes_REPUBLICAN
# 0             ACCOMACK                     7578                       9172
# 1            ALBEMARLE                    42466                      20804
# 2      ALEXANDRIA CITY                    66240                      14544
# 3            ALLEGHANY                     2243                       5859
# 4               AMELIA                     2411                       5390
# ..                 ...                      ...                        ...
# 128  WILLIAMSBURG CITY                     4790                       1963
# 129    WINCHESTER CITY                     6610                       5221
# 130               WISE                     3110                      13366
# 131              WYTHE                     3143                      11733
# 132               YORK                    17683                      20241
#
# [133 rows x 3 columns]

# %%
rep_dem_df.to_csv('rep_dem_votes.csv')
